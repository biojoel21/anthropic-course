# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()

# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    # system = """ 
    # You are a patient math tutor.
    # Do not directly answer a student's questions.
    # Guide them to a solution step by step.
    # """
    message = client.messages.create(**params
    )
    return message.content[0].text

# %%
messages = []
system = """ 
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
    """
add_user_message(messages, "How do I solve 5x+3=2 for x?")
response = chat(messages,system=system)
print(response)
# Out:
# Let's work through this together step by step!
#
# Your goal is to **get x by itself** on one side of the equation.
#
# **First, let's look at the equation:**
# 5x + 3 = 2
#
# There are two things "happening" to x here:
# 1. It's being multiplied by 5
# 2. Then 3 is being added
#
# **Let's start by dealing with the +3.**
#
# What could you do to *both sides* of the equation to start removing that +3? What is the opposite of adding 3?

# %%
messages = []
add_user_message(messages, "Write a Python function that checks a string for duplicate characters")
answer = chat(messages, system="You are a Python engineer who writes very concise code.")
answer
# Out:
# 'Here\'s a concise Python function that checks for duplicate characters:\n\n```python\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n```\n\n**Examples:**\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' appears twice)\nprint(has_duplicates("world"))   # False (all unique)\nprint(has_duplicates("python"))  # False (all unique)\nprint(has_duplicates("abcabc"))  # True  (a, b, c repeat)\n```\n\nIf you also want to **identify which characters are duplicates**:\n\n```python\ndef find_duplicates(s):\n    return {char for char in s if s.count(char) > 1}\n```\n\n**Examples:**\n```python\nprint(find_duplicates("hello"))   # {\'l\'}\nprint(find_duplicates("abcabc"))  # {\'a\', \'b\', \'c\'}\nprint(find_duplicates("python"))  # set() (empty - no duplicates)\n```\n\n**How they work:**\n- `has_duplicates` — converts the string to a `set` (which removes duplicates) and compares lengths. If they differ, duplicates exist.\n- `find_duplicates` — uses a set comprehension to collect characters that appear more than once.'
