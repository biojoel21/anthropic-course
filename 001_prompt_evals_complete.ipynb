# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_s3_buckets_from_cloudtrail(log_data):\n    \"\"\"Extract all S3 bucket names from CloudTrail logs\"\"\"\n    buckets = set()\n    \n    if isinstance(log_data, str):\n        try:\n            log_data = json.loads(log_data)\n        except json.JSONDecodeError:\n            pass\n    \n    def find_buckets(obj):\n        if isinstance(obj, dict):\n            for key, value in obj.items():\n                if key.lower() in ['bucket', 'bucketname', 's3bucket']:\n                    if isinstance(value, str):\n                        buckets.add(value)\n                if isinstance(value, (dict, list)):\n                    find_buckets(value)\n        elif isinstance(obj, list):\n            for item in obj:\n                find_buckets(item)\n    \n    find_buckets(log_data)\n    \n    return sorted(list(buckets))\n\n\nif __name__ == \"__main__\":\n    input_data = sys.stdin.read()\n    result = extract_s3_buckets_from_cloudtrail(input_data)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Extract all S3 bucket names from AWS CloudTrail logs in JSON format",
#       "format": "regex",
#       "solution_criteria": "Regex pattern should match S3 bucket names (lowercase letters, numbers, hyphens) and correctly extract them from bucket ARNs like 'arn:aws:s3:::my-bucket-name'"
#     },
#     "score": 6.5,
#     "reasoning": "The solution demonstrates good JSON handling practices but fundamentally fails the stated requirement. It relies on dictionary key inspection rather than the regex-based ARN parsing specified in the criteria. CloudTrail logs often store bucket information within request parameters or resource ARNs rather than as direct 'bucket' keys. For example, an S3 PutObject operation would have the bucket name buried in 'requestParameters' or as part of an ARN string like 'arn:aws:s3:::my-bucket-name/key', which this solution cannot extract. The code would miss most real-world CloudTrail scenarios."
#   },
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_allowed_actions(policy_json):\n    \"\"\"Extract all allowed actions from AWS IAM policy JSON\"\"\"\n    try:\n        if isinstance(policy_json, str):\n            policy = json.loads(policy_json)\n        else:\n            policy = policy_json\n        \n        allowed_actions = set()\n        \n        if 'Statement' in policy:\n            for statement in policy['Statement']:\n                if statement.get('Effect') == 'Allow':\n                    actions = statement.get('Action', [])\n                    if isinstance(actions, str):\n                        allowed_actions.add(actions)\n                    elif isinstance(actions, list):\n                        allowed_actions.update(actions)\n        \n        return sorted(list(allowed_actions))\n    except (json.JSONDecodeError, TypeError, KeyError):\n        return []\n\nif __name__ == \"__main__\":\n    if len(sys.argv) > 1:\n        policy_input = sys.argv[1]\n    else:\n        policy_input = sys.stdin.read()\n    \n    result = extract_allowed_actions(policy_input)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS IAM policy JSON and extract all allowed actions",
#       "format": "python",
#       "solution_criteria": "Function should return a list of all actions from the 'Action' field(s) in the policy document, handling both string and array formats, and supporting wildcard actions like 's3:*'"
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully addresses the core requirement of parsing IAM policy JSON and extracting allowed actions from both string and array formats. Error handling is well-implemented. However, it has notable limitations: it doesn't recognize or process wildcard actions beyond literal string matching, lacks support for 'NotAction' statements (which negate specific actions), and only handles simple, flat policy structures. While wildcard handling wasn't explicitly required in the criteria, the criteria specifically mentions support for 'wildcard actions like s3:*', which this solution only achieves in the most basic sense (storing them as strings without interpretation). For production use, these gaps could cause incomplete or misleading action extraction."
#   },
#   {
#     "output": "\n{\n  \"Variables\": {\n    \"ENVIRONMENT\": \"development\",\n    \"LOG_LEVEL\": \"INFO\",\n    \"TIMEOUT\": \"30\",\n    \"MEMORY_SIZE\": \"128\",\n    \"DATABASE_HOST\": \"localhost\",\n    \"DATABASE_PORT\": \"5432\",\n    \"DATABASE_NAME\": \"mydb\",\n    \"DATABASE_USER\": \"admin\",\n    \"API_KEY\": \"\",\n    \"API_ENDPOINT\": \"https://api.example.com\",\n    \"REGION\": \"us-east-1\",\n    \"S3_BUCKET\": \"my-bucket\",\n    \"SNS_TOPIC_ARN\": \"arn:aws:sns:us-east-1:123456789012:my-topic\",\n    \"SQS_QUEUE_URL\": \"https://sqs.us-east-1.amazonaws.com/123456789012/my-queue\",\n    \"DYNAMODB_TABLE\": \"my-table\",\n    \"ENABLE_DEBUG\": \"false\",\n    \"MAX_RETRIES\": \"3\",\n    \"CACHE_TTL\": \"3600\",\n    \"WEBHOOK_SECRET\": \"\"\n  }\n}\n",
#     "test_case": {
#       "task": "Generate a JSON template for an AWS Lambda function environment variables configuration",
#       "format": "json",
#       "solution_criteria": "JSON object should define environment variables with proper structure including database connection strings, API endpoints, and feature flags with realistic AWS resource values"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates a solid understanding of AWS Lambda environment variable structure and includes realistic resource identifiers. However, it conflates Lambda configuration with environment variables and critically overlooks security best practices for sensitive data. The template would cause production issues if implemented as-is due to hardcoded secrets and misplaced configuration properties."
#   }
# ]
